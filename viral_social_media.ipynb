# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Cleaned_Viral_Social_Media_Trends.csv")
df.shape
df.info
# Out:
# <bound method DataFrame.info of         Post_ID   Post_Date   Platform     Hashtag Content_Type     Region  \
# 0        Post_1  2022-01-13     TikTok  #Challenge        Video         UK
# 1        Post_2  2022-05-13  Instagram  #Education       Shorts      India
# 2        Post_3  2022-01-07    Twitter  #Challenge        Video     Brazil
# 3        Post_4  2022-12-05    YouTube  #Education       Shorts  Australia
# 4        Post_5  2023-03-23     TikTok      #Dance         Post     Brazil
# ...         ...         ...        ...         ...          ...        ...
# 4995  Post_4996  2023-05-05    YouTube  #Education        Video      Japan
# 4996  Post_4997  2023-09-07  Instagram  #Education        Video         UK
# 4997  Post_4998  2022-06-12    YouTube    #Fashion       Shorts        USA
# 4998  Post_4999  2023-05-23  Instagram     #Gaming       Shorts     Canada
# 4999  Post_5000  2022-12-21  Instagram    #Fashion         Reel      Japan
#
# ...

# %%
count = df['Post_ID']

# %%
print(df.columns)
# Out:
# Index(['Post_ID', 'Post_Date', 'Platform', 'Hashtag', 'Content_Type', 'Region',
#        'Views', 'Likes', 'Shares', 'Comments', 'Engagement_Level'],
#       dtype='object')
